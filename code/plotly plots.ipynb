# %%
import pandas as pd
import numpy as np
import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import datetime
import warnings
warnings.filterwarnings('ignore')

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.figure_factory as ff

py.offline.init_notebook_mode(connected=True)

from math import floor
from plotly import tools
from plotly.graph_objs import *
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = pd.read_csv("../data/cleaned_data.csv")

# %%
data["profit"] = data["revenue"] - data["budget"]

# %%
data["profit"].describe()
# Out:
# count    4.790000e+03
# mean     5.336400e+07
# std      1.361221e+08
# min     -1.657101e+08
# 25%     -7.985852e+05
# 50%      2.602056e+06
# 75%      5.546026e+07
# max      2.550965e+09
# Name: profit, dtype: float64

# %%
data[data["profit"]==data["profit"].max()]
# Out:
#       budget                                             genres  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
#
#                                             keywords original_language  \
# 0  ['culture clash', 'future', 'space war', 'spac...                en
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
#
#                                 production_companies  \
# 0  ['Ingenious Film Partners', 'Twentieth Century...
#
#                              production_countries release_date     revenue  \
# 0  ['United States of America', 'United Kingdom']   2009-12-10  2787965087
#
#       ...      vote_average vote_count   title             cast  \
# 0     ...               7.2      11800  Avatar  Sam Worthington
#
#                                                 crew  year month  day  dow  \
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...  2009    12   10    3
#
#        profit
# 0  2550965087
#
# [1 rows x 22 columns]

# %%
profit_by_dow = data[data["year"]>1990].groupby(["dow"]).profit.mean().reset_index()

# %%
bar_data = [go.Bar(x=['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']\
                   , y=profit_by_dow["profit"])]

py.offline.iplot({ 'data': bar_data,
            'layout': {
               'title': 'Average Profit by Day of Week',
               'xaxis': {
                 'title': 'Day of Week'},
               'yaxis': {
                'title': 'Profit'}
        }})
# Out:
# <div id="eafd1051-cc78-4d10-b2c4-b83f785e2283" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eafd1051-cc78-4d10-b2c4-b83f785e2283", [{"type": "bar", "x": ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"], "y": [66927616.756476685, 87546668.10561056, 101267039.7826087, 64039338.8091133, 29284123.65575559, 43012336.96226415, 31454542.925531916]}], {"title": "Average Profit by Day of Week", "xaxis": {"title": "Day of Week"}, "yaxis": {"title": "Profit"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# #### Release movies on Tuesday

# %% [markdown]
# ### Violin Plots

# %%
def extract_decade(x):
    return str(floor(x/10)*10)+"s"

# %%
data["decade"] = data["year"].apply(extract_decade)

# %%
df = data

# %%
df = df.sort_values(by=['decade'], ascending=True)

# %%
df.groupby(['decade']).size()
# Out:
# decade
# 1910s       1
# 1920s       4
# 1930s      15
# 1940s      25
# 1950s      27
# 1960s      71
# 1970s     109
# 1980s     278
# 1990s     778
# 2000s    2044
# 2010s    1438
# dtype: int64

# %%
df[df['decade'] == '1910s']
# Out:
#       budget     genres                                           keywords  \
# 4581  385907  ['Drama']  ['usa', 'naivety', 'intolerance', 'mill', 'mar...
#
#      original_language                                           overview  \
# 4581                en  The story of a poor young woman, separated by ...
#
#       popularity                               production_companies  \
# 4581    3.232447  ['Triangle Film Corporation', 'Wark Producing ...
#
#               production_countries release_date  revenue   ...    vote_count  \
# 4581  ['United States of America']   1916-09-04  8394751   ...            60
#
#             title          cast  \
# 4581  Intolerance  Lillian Gish
#
#                                                    crew  year month day  dow  \
# 4581  [{'credit_id': '577fe3e79251415db5000bf2', 'de...  1916     9   4    0
#
#        profit  decade
# 4581  8008844   1910s
#
# [1 rows x 23 columns]

# %% [markdown]
# ### get rid of the 1910's decade since it has only 1 movie

# %%
df = df[df['decade'] != '1910s']

# %%
da = []
for i in range(0,len(pd.unique(df['decade']))):
    trace = {
            "type": 'violin',
            "x": df['decade'][df['decade'] == pd.unique(df['decade'])[i]],
            "y": df['vote_average'][df['decade'] == pd.unique(df['decade'])[i]],
            "name": pd.unique(df['decade'])[i],
            "box": {
                "visible": True
            },
            "meanline": {
                "visible": True
            }
        }
    da.append(trace)

        
fig = {
    "data": da,
    "layout" : {
        "title": "Average Movie Ratings by Decade",
            "xaxis" : dict(title = 'Decade', autotick=False, showticklabels=True),
            "yaxis" : dict(title = 'Average Rating')
    }
}

iplot(fig, validate = False)
# Out:
# <div id="33a4a383-59f8-474e-bb9a-3fcad8f3a8b2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("33a4a383-59f8-474e-bb9a-3fcad8f3a8b2", [{"type": "violin", "x": ["1920s", "1920s", "1920s", "1920s"], "y": [8.0, 7.0, 7.6, 5.0], "name": "1920s", "box": {"visible": true}, "meanline": {"visible": true}}, {"type": "violin", "x": ["1930s", "1930s", "1930s", "1930s", "1930s", "1930s", "1930s", "1930s", "1930s", "1930s", "1930s", "1930s", "1930s", "1930s", "1930s"], "y": [6.1, 6.8, 7.4, 5.1, 4.8, 6.2, 8.4, 7.7, 7.7, 7.4, 7.2, 7.9, 6.9, 6.1, 8.1], "name": "1930s", "box": {"visible": true}, "meanline": {"visible": true}}, {"type": "violin", "x": ["1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s", "1940s"], "y": [6.8, 6.4, 7.4, 7.7, 6.8, 8.0, 6.5, 7.9, 7.0, 6.6, 7.2, 5.8, 6.2, 7.6, 6.0, 7.0, 7.3, 7.1, 6.8, 6.6, 7.3, 6.2, 6.2, 6.9, 7.2], "name": "1940s", "box": {"visible": true}, "meanline": {"visible": true}}, {"type": "violin", "x": ["1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s", "1950s"], "y": [6.4, 6.6, 6.8, 7.6, 7.8, 6.7, 7.4, 6.9, 7.7, 8.2, 7.6, 6.9, 7.3, 5.5, 7.2, 6.4, 7.8, 6.7, 6.9, 8.0, 6.0, 5.4, 6.9, 7.0, 8.2, 7.6, 8.0], "name": "1950s", "box": {"visible": true}, "meanline": {"visible": true}}, {"type": "violin", "x": ["1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s", "1960s"], "y": [7.5, 7.4, 6.5, 6.5, 7.4, 6.3, 7.3, 7.0, 7.2, 7.0, 7.3, 7.5, 7.6, 7.1, 6.2, 7.6, 7.5, 7.3, 8.2, 6.5, 6.5, 6.0, 7.4, 6.6, 6.2, 6.4, 8.1, 6.2, 7.0, 7.4, 7.4, 6.2, 6.7, 6.1, 7.4, 7.4, 6.7, 8.1, 7.8, 4.3, 8.0, 7.6, 6.5, 7.3, 6.1, 5.7, 6.3, 7.5, 7.2, 4.4, 5.4, 7.5, 7.1, 7.0, 6.1, 7.6, 6.8, 7.4, 7.3, 8.0, 7.6, 6.1, 6.9, 7.8, 6.1, 6.9, 7.9, 6.7, 7.2, 6.0, 8.1], "name": "1960s", "box": {"visible": true}, "meanline": {"visible": true}}, {"type": "violin", "x": ["1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s", "1970s"], "y": [7.2, 7.0, 6.7, 7.3, 5.1, 7.5, 7.2, 7.5, 7.4, 7.4, 7.6, 6.1, 7.5, 7.2, 6.9, 7.4, 7.6, 5.9, 5.5, 6.2, 7.3, 6.6, 5.4, 6.6, 8.0, 7.5, 6.3,  ...

# %% [markdown]
# #### movies were better in the 1990's than the 2010's

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'keywords', 'original_language', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages',
#        'vote_average', 'vote_count', 'title', 'cast', 'crew', 'year', 'month',
#        'day', 'dow', 'profit', 'decade'],
#       dtype='object')

# %% [markdown]
# ### Bubble Chart

# %%
layout = go.Layout(
    title='Profit vs. Budget',
    xaxis=dict(
        title='Budget',
        gridcolor='rgb(255, 255, 255)',
        range=[0, 4e8],
        zerolinewidth=1,
        ticklen=5,
        gridwidth=2,
    ),
    yaxis=dict(
        title='Profit',
        gridcolor='rgb(255, 255, 255)',
        zerolinewidth=1,
        ticklen=5,
        gridwidth=2,
    )
)
data = [go.Scatter(
    x=df.budget.values, # Budget
    y=df.profit.values,  # Gross
    mode='markers',
    text= df.title.values, # Movie Titles
    marker=dict(
        size=3*(df.vote_average),
        sizeref=1.0,
        color=df.vote_average.values,
        colorbar=ColorBar(title='Average Rating'),
        showscale=True,
        colorscale='Viridis'
    ))]
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="0bdd9016-7c6e-40ed-8a58-4b2687a79bc9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0bdd9016-7c6e-40ed-8a58-4b2687a79bc9", [{"type": "scatter", "x": [92620000, 245000, 0, 379000, 3950000, 1200000, 2777000, 200000, 2000000, 4, 0, 325000, 4000000, 609000, 1644736, 1500000, 1488423, 439000, 1, 1250000, 0, 1250000, 1288000, 2000000, 3180000, 2000000, 878000, 2361000, 3700000, 2280000, 2160000, 1000000, 2100000, 2627000, 0, 3000000, 1600000, 858000, 0, 1500000, 0, 6000000, 2600000, 2300000, 4000000, 4000000, 5000000, 1800000, 2540800, 210000, 3500000, 0, 3000000, 350000, 730000, 2300000, 3768785, 1000000, 1650000, 4100000, 0, 1250000, 4500000, 910000, 5000000, 5000000, 1200000, 8250000, 2000000, 3000000, 2883848, 3200000, 3600000, 9500000, 8000000, 3200000, 17000000, 2900000, 9400000, 2500000, 6000000, 3000000, 3900000, 300000, 2500000, 3800000, 6244087, 2500000, 560000, 806948, 20000000, 5500000, 2686000, 6000000, 950000, 20000000, 3000000, 3000000, 3500000, 0, 3500000, 17000000, 0, 31115000, 0, 6000000, 11000000, 0, 1200000, 4000000, 100000, 1800000, 200000, 6500000, 2000000, 0, 9000000, 0, 114000, 10000000, 62000, 1455000, 0, 120000, 10000000, 1377800, 2000000, 4000000, 8200000, 0, 2000000, 3000000, 1000000, 2000000, 15000000, 4000000, 950000, 10500000, 1800000, 5800000, 19000000, 5000000, 8000000, 6500000, 2000000, 0, 0, 8000000, 6000000, 1600000, 3000000, 300000, 0, 1700000, 7000000, 20000000, 777000, 22000000, 750000, 20000000, 1700000, 35000000, 12000000, 2090000, 12000000, 2000000, 1300000, 1000000, 1000000, 7000000, 0, 20000000, 22000000, 9000000, 0, 7000000, 2500000, 6000000, 2600000, 1200000, 0, 500000, 15000000, 0, 7200000, 1800000, 0, 2800000, 85000, 9000000, 2700000, 35000000, 17000000, 9250000, 11000000, 2000000, 11000000, 24000000, 10000, 25485000, 0, 3716946, 0, 3500000, 0, 25000000, 400000, 35000000, 400000, 0, 0, 6000000, 2800000, 0, 3400000, 3800000, 0, 5000000, 18000000, 4000000, 4000000, 0, 14000000, 11, 5500000, 55000000, 5500000, 34000000, 300000, 0, 150000, 31500000, 3000000, 0, 11000000, 500000, 27000, 14000000, 11000000, 4638783, 0, 5000000, 5000000, 13000000, 0, 2000000, 600000, 3000000, 12000, 600000, 2700000, 25000000, 0, 2000000, 0, 0, 8000000, 15000000, 19000000, 0, 3500000, 4000000, 27500000, 0, 30000000, 0, 5000000, 0, 14000000, 4000000, 0, 12000000, 25000000, 15000000, 15000000, 0, 8000000, 5000000, 7500000, 15000000, 5000000, 0, 5000000, 0, 5000000, 25000000, 27000000, 0, 21000000, 4500000, 0, 4500000, 4500000, 15000000, 55000000, 0, 55000000, 5000000, 5000000, 8000000, 25000000, 27000000, 15000000, 7500000, 0, 54000000, 12300000, 4700000, 27000000, 15000000, 18000000, 0, 4500000, 13000000, 63000000, 3000000, 40000000, 25000000, 0, 5000000, 13000000, 6500000, 4300000, 0, 6500000, 0, 2800000, 8200000, 70000000, 15000000, 8000000, 24000000, 18000000, 14000000, 25000000, 3000000, 0, 3000000, 6000000, 3000000, 44000000, 15000000, 4200000, 6000000, 44000000, 6000000, 0, 7000000, 3000000, 6000000, 4000000, 6400000, 0, 32000000, 4000000, 15000000, 3600000, 40000000, 0, 25000000, 23000000, 48000000, 0, 5500000, 7000000, 8000000, 5500000, 0, 2000000, 6500000, 4000000, 5100000, 5000000, 25000000, 22000000, 40000000, 58000000, 4000000, 46000000, 2600000, 0, 0, 23000000, 2500000, 7000000, 26000000, 22700000, 16000000, 7000000, 7000000, 3500000, 15000000, 3500000, 5952000, 2000000, 2200000, 1300000, 15000000, 14000000, 28000000, 10000000, 10000000, 18000000, 18000000, 16400000, 12000000, 12000000, 0, 9000000, 18000000, 28000000, 15000000, 14000000, 10700000, 9000000, 0, 17000000, 40600000, 17000000, 16000000, 16000000, 10000000, 160000, 1100000, 8500000, 10000000, 0, 5000000, 1000000, 9000000, 1000000, 28000000, 18000000, 18000000, 10000000, 15000000, 0, 18000000, 1800000, 35000000, 0, 9300000, 31000000, 18000000 ...

# %% [markdown]
# ### Runtime vs Profit
#
# ### Actors vs Profit
#
# ### Directors vs Profit
#
# ### Month vs Profit

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'keywords', 'original_language', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages',
#        'vote_average', 'vote_count', 'title', 'cast', 'crew', 'year', 'month',
#        'day', 'dow', 'profit', 'decade'],
#       dtype='object')

# %%
df.head().transpose()
# Out:
#                                                                    2638  \
# budget                                                         92620000
# genres                                     ['Drama', 'Science Fiction']
# keywords              ['man vs machine', 'underground world', 'inven...
# original_language                                                    de
# overview              In a futuristic city sharply divided between t...
# popularity                                                      32.3515
# production_companies     ['Paramount Pictures', 'Universum Film (UFA)']
# production_countries                                        ['Germany']
# release_date                                                 1927-01-10
# revenue                                                          650422
# runtime                                                             153
# spoken_languages                                        ['No Language']
# vote_average                                                          8
# vote_count                                                          657
# title                                                        Metropolis
# cast                                                      Brigitte Helm
# crew                  [{'credit_id': '52fe420fc3a36847f8000c55', 'de...
# year                                                               1927
# month                                                                 1
# day                                                                  10
# dow                                                                   0
# profit                                                        -91969578
# decade                                                            1920s
#
#                                                                    4650  \
# budget                                                           245000
# genres                                      ['Drama', 'Romance', 'War']
# keywords                                 ['world war i', 'silent film']
# original_language                                                    en
# overview              The story of an idle rich boy who joins the US...
# popularity                                                     0.785744
# production_companies                      ['Metro-Goldwyn-Mayer (MGM)']
# production_countries                       ['United States of America']
# release_date                                                 1925-11-05
# revenue                                                        22000000
# runtime                                                             151
# spoken_languages                                                     []
# vote_average                                                          7
# vote_count                                                           21
# title                                                    The Big Parade
# cast                                                       John Gilbert
# crew                  [{'credit_id': '52fe4381c3a36847f805922b', 'de...
# year                                                               1925
# month                                                                11
# day                                                                   5
# dow                                                                   3
# profit                                                         21755000
# decade                                                            1920s
#
#                                                                    4448  \
# budget                                                                0
# genres                                 ['Drama', 'Thriller', 'Romance']
# keywords              ['london england', 'casino', 'irony', 'forbidd...
# original_language                                                    de
# overview              The rise and inevitable fall of an amoral but ...
# popularity                                                      1.82418
# production_companies                                     ['Nero Films']
# production_countries                                        ['Germany']
# release_date                                                 1929-01-30
# revenue                                                               0
# runtime                                                             109
# spoken_languages                                            ['Deutsch']
# vote_average                                                        7.6
# vote_count                                                           45
# title                                                     Pandora's Box
# cast                                                      Louise Brooks
# crew                  [{'credit_id': '52fe428ac3a36847f8026e81', 'de...
# year                                                               1929
# month                                                                 1
# day                                                                  30
# dow                                                                   2
# profit                                                                0
# decade                                                            1920s
#
#                                                                    4583  \
# budget                                                           379000
# genres                                    ['Drama', 'Music', 'Romance']
# keywords              ['musical', 'singer', 'pre-code', 'wisecrack h...
# original_language                                                    en
# overview              Harriet and Queenie Mahoney, a vaudeville act,...
# popularity                                                     0.968865
# production_companies                      ['Metro-Goldwyn-Mayer (MGM)']
# production_countries                       ['United States of America']
# release_date                                                 1929-02-08
# revenue                                                         4358000
# runtime                                                             100
# spoken_languages                                            ['English']
# vote_average                                                          5
# vote_count                                                           19
# title                                               The Broadway Melody
# cast                                                       Charles King
# crew                  [{'credit_id': '5647d9b9c3a368260100563e', 'de...
# year                                                               1929
# month                                                                 2
# day                                                                   8
# dow                                                                   4
# profit                                                          3979000
# decade                                                            1920s
#
#                                                                    3802
# budget                                                          3950000
# genres                                   ['Action', 'Drama', 'History']
# keywords              ['world war i', 'zeppelin', 'royal air force',...
# original_language                                                    en
# overview              Two brothers attending Oxford enlist with the ...
# popularity                                                      8.48412
# production_companies                              ['The Caddo Company']
# production_countries                       ['United States of America']
# release_date                                                 1930-11-15
# revenue                                                         8000000
# runtime                                                             127
# spoken_languages                     ['Français', 'English', 'Deutsch']
# vote_average                                                        6.1
# vote_count                                                           19
# title                                                     Hell's Angels
# cast                                                           Ben Lyon
# crew                  [{'credit_id': '52fe443bc3a368484e017347', 'de...
# year                                                               1930
# month                                                                11
# day                                                                  15
# dow                                                                   5
# profit                                                          4050000
# decade                                                            1930s

# %% [markdown]
# ### Runtime vs Profit

# %% [markdown]
# ### Remove movies with a runtime of 0

# %%
df2 = df[df.runtime > 20]
df2 = df2[df.vote_average>3]
# Out:
# /Users/mbk/anaconda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
layout = go.Layout(
    title='Profit vs. Runtime',
    xaxis=dict(
        title='Runtime',
        gridcolor='rgb(255, 255, 255)',
        range=[50, 250],
        zerolinewidth=1,
        ticklen=5,
        gridwidth=2,
    ),
    yaxis=dict(
        title='Profit',
        gridcolor='rgb(255, 255, 255)',
        zerolinewidth=1,
        ticklen=5,
        gridwidth=2,
    )
)
data = [go.Scatter(
    x=df2.runtime.values, # Budget
    y=df2.profit.values,  # Gross
    mode='markers',
    text= df2.title.values, # Movie Titles
    marker=dict(
        size=3*(df2.vote_average),
        sizeref=1.0,
        color=df2.vote_average.values,
        colorbar=ColorBar(title='Average Rating'),
        showscale=True,
        colorscale='Viridis'
    ))]
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="b21e5e3e-eb00-442c-a7c9-33f0c8f58db3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b21e5e3e-eb00-442c-a7c9-33f0c8f58db3", [{"type": "scatter", "x": [153.0, 151.0, 109.0, 100.0, 127.0, 115.0, 102.0, 66.0, 106.0, 89.0, 101.0, 105.0, 238.0, 101.0, 126.0, 129.0, 83.0, 89.0, 87.0, 118.0, 88.0, 101.0, 130.0, 118.0, 130.0, 119.0, 102.0, 101.0, 102.0, 124.0, 119.0, 100.0, 172.0, 120.0, 68.0, 133.0, 103.0, 70.0, 128.0, 111.0, 96.0, 144.0, 88.0, 87.0, 105.0, 152.0, 127.0, 125.0, 103.0, 80.0, 149.0, 87.0, 161.0, 96.0, 85.0, 107.0, 107.0, 89.0, 118.0, 135.0, 126.0, 92.0, 116.0, 108.0, 139.0, 139.0, 99.0, 171.0, 207.0, 108.0, 122.0, 136.0, 113.0, 117.0, 149.0, 123.0, 154.0, 136.0, 163.0, 110.0, 152.0, 146.0, 120.0, 110.0, 92.0, 123.0, 145.0, 112.0, 88.0, 109.0, 199.0, 130.0, 109.0, 110.0, 103.0, 158.0, 128.0, 125.0, 121.0, 95.0, 134.0, 170.0, 111.0, 248.0, 94.0, 139.0, 197.0, 123.0, 161.0, 172.0, 69.0, 95.0, 99.0, 142.0, 153.0, 99.0, 98.0, 85.0, 96.0, 178.0, 82.0, 113.0, 25.0, 95.0, 153.0, 105.0, 134.0, 124.0, 174.0, 116.0, 129.0, 186.0, 128.0, 115.0, 216.0, 143.0, 110.0, 149.0, 114.0, 133.0, 188.0, 175.0, 111.0, 131.0, 82.0, 123.0, 107.0, 122.0, 110.0, 113.0, 100.0, 91.0, 94.0, 88.0, 124.0, 135.0, 110.0, 121.0, 107.0, 116.0, 93.0, 132.0, 172.0, 109.0, 102.0, 88.0, 114.0, 119.0, 89.0, 125.0, 90.0, 98.0, 175.0, 119.0, 107.0, 121.0, 98.0, 175.0, 93.0, 97.0, 107.0, 110.0, 183.0, 125.0, 120.0, 104.0, 97.0, 106.0, 83.0, 181.0, 118.0, 102.0, 91.0, 125.0, 117.0, 89.0, 124.0, 134.0, 89.0, 144.0, 99.0, 121.0, 91.0, 116.0, 127.0, 128.0, 93.0, 113.0, 91.0, 106.0, 117.0, 110.0, 111.0, 167.0, 94.0, 121.0, 86.0, 113.0, 121.0, 105.0, 93.0, 155.0, 118.0, 145.0, 105.0, 143.0, 129.0, 126.0, 80.0, 142.0, 97.0, 153.0, 133.0, 117.0, 184.0, 97.0, 64.0, 125.0, 121.0, 106.0, 106.0, 123.0, 118.0, 200.0, 86.0, 121.0, 83.0, 95.0, 93.0, 225.0, 109.0, 109.0, 129.0, 104.0, 98.0, 199.0, 120.0, 92.0, 99.0, 107.0, 104.0, 94.0, 131.0, 110.0, 126.0, 94.0, 124.0, 118.0, 119.0, 94.0, 98.0, 100.0, 94.0, 98.0, 98.0, 87.0, 163.0, 97.0, 109.0, 105.0, 88.0, 115.0, 89.0, 110.0, 107.0, 116.0, 133.0, 118.0, 116.0, 90.0, 102.0, 96.0, 104.0, 110.0, 104.0, 100.0, 107.0, 99.0, 100.0, 124.0, 99.0, 102.0, 125.0, 99.0, 112.0, 127.0, 69.0, 101.0, 193.0, 154.0, 136.0, 109.0, 123.0, 107.0, 102.0, 87.0, 137.0, 119.0, 88.0, 96.0, 121.0, 105.0, 98.0, 107.0, 108.0, 94.0, 88.0, 107.0, 139.0, 124.0, 126.0, 119.0, 124.0, 119.0, 133.0, 117.0, 95.0, 97.0, 98.0, 97.0, 96.0, 114.0, 114.0, 99.0, 219.0, 124.0, 121.0, 99.0, 86.0, 120.0, 91.0, 108.0, 104.0, 133.0, 95.0, 132.0, 84.0, 130.0, 116.0, 170.0, 163.0, 127.0, 96.0, 123.0, 96.0, 89.0, 95.0, 87.0, 95.0, 120.0, 110.0, 103.0, 96.0, 117.0, 191.0, 108.0, 127.0, 95.0, 140.0, 91.0, 134.0, 115.0, 89.0, 98.0, 100.0, 127.0, 96.0, 98.0, 164.0, 103.0, 92.0, 93.0, 88.0, 87.0, 90.0, 92.0, 102.0, 107.0, 145.0, 131.0, 91.0, 103.0, 103.0, 129.0, 129.0, 100.0, 122.0, 107.0, 137.0, 109.0, 118.0, 126.0, 149.0, 114.0, 87.0, 107.0, 102.0, 116.0, 96.0, 129.0, 90.0, 91.0, 99.0, 97.0, 108.0, 84.0, 97.0, 91.0, 91.0, 94.0, 127.0, 107.0, 160.0, 101.0, 114.0, 124.0, 103.0, 91.0, 126.0, 96.0, 90.0, 161.0, 122.0, 110.0, 98.0, 137.0, 118.0, 103.0, 114.0, 195.0, 229.0, 92.0, 106.0, 82.0, 79.0, 89.0, 93.0, 135.0, 96.0, 101.0, 107.0, 173.0, 99.0, 106.0, 92.0, 157.0, 90.0, 111.0, 98.0, 98.0, 108.0, 105.0, 99.0, 90.0, 100.0, 117.0, 85.0, 117.0, 108.0, 97.0, 98.0, 121.0, 87.0, 107.0, 78.0, 89.0, 119.0, 100.0, 113.0, 90.0, 100.0, 132.0, 88.0, 87.0, 131.0, 92.0, 104.0, 132.0, 113.0, 114.0, 99.0, 115.0, 108.0, 89.0, 115.0, 116.0, 107.0, 111.0, 117.0, 94.0, 129.0, 105.0, 144.0, 89.0, 109.0, 92.0, 116.0, 90.0, 113.0, 125.0, 116.0, 101.0, 125.0, 134.0, 114.0, 106.0, 121.0, 96.0, 111.0, 97.0, 87.0, 103.0, 107.0, 132.0, 105.0, 113.0, 103.0, 139.0, 101.0, 99.0, 97.0, 96.0, 100.0, 91.0, 110.0, 145.0,  ...
